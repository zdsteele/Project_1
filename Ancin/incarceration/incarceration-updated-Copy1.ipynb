# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

MARIJUANA_LEGALIZATION_YEAR = 2012

# %%
# Load in csv
crime_df = pd.read_csv("Resources/incarceration_by_state.csv")
crime_df.head(10)
# Out:
#   jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 0      FEDERAL           False  2001          149852                    NaN
# 1      ALABAMA           False  2001           24741                  False
# 2       ALASKA            True  2001            4570                  False
# 3      ARIZONA           False  2001           27710                  False
# 4     ARKANSAS           False  2001           11489                  False
# 5   CALIFORNIA           False  2001          157142                  False
# 6     COLORADO           False  2001           17278                  False
# 7  CONNECTICUT            True  2001           17507                  False
# 8     DELAWARE            True  2001            6841                  False
# 9      FLORIDA           False  2001           72404                  False
#
#   crimes_estimated  state_population  violent_crime_total  \
# 0              NaN               NaN                  NaN
# 1            False         4468912.0              19582.0
# 2            False          633630.0               3735.0
# 3            False         5306966.0              28675.0
# 4            False         2694698.0              12190.0
# 5            False        34600463.0             212867.0
# 6            False         4430989.0              15492.0
# 7            False         3434602.0              11492.0
# 8            False          796599.0               4868.0
# 9            False        16373330.0             130713.0
#
#    murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 0                  NaN          NaN           NaN      NaN          NaN
# 1                379.0       1369.0           NaN   5584.0      12250.0
# 2                 39.0        501.0           NaN    514.0       2681.0
# 3                400.0       1518.0           NaN   8868.0      17889.0
# 4                148.0        892.0           NaN   2181.0       8969.0
# 5               2206.0       9960.0           NaN  64614.0     136087.0
# 6                158.0       1930.0           NaN   3555.0       9849.0
# 7                105.0        639.0           NaN   4183.0       6565.0
# 8                 23.0        420.0           NaN   1156.0       3269.0
# 9                874.0       6641.0           NaN  32867.0      90331.0
#
#    property_crime_total  burglary   larceny  vehicle_theft
# 0                   NaN       NaN       NaN            NaN
# 1              173253.0   40642.0  119992.0        12619.0
# 2               23160.0    3847.0   16695.0         2618.0
# 3              293874.0   54821.0  186850.0        52203.0
# 4               99106.0   22196.0   69590.0         7320.0
# 5             1134189.0  232273.0  697739.0       204177.0
# 6              170887.0   28533.0  121360.0        20994.0
# 7               95299.0   17159.0   65762.0        12378.0
# 8               27399.0    5144.0   19476.0         2779.0
# 9              782517.0  176052.0  516548.0        89917.0

# %%
crime_df_colorado=crime_df[crime_df['jurisdiction']=='COLORADO']
crime_df_colorado.head(20)
# Out:
#     jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 6       COLORADO           False  2001           17278                  False
# 57      COLORADO           False  2002           18636                  False
# 108     COLORADO           False  2003           19450                  False
# 159     COLORADO           False  2004           19655                  False
# 210     COLORADO           False  2005           21063                  False
# 261     COLORADO           False  2006           22051                  False
# 312     COLORADO           False  2007           22666                  False
# 363     COLORADO           False  2008           23211                  False
# 414     COLORADO           False  2009           22725                  False
# 465     COLORADO           False  2010           22752                  False
# 516     COLORADO           False  2011           21862                  False
# 567     COLORADO           False  2012           20328                  False
# 618     COLORADO           False  2013           20184                  False
# 669     COLORADO           False  2014           20469                  False
# 720     COLORADO           False  2015           19959                  False
# 771     COLORADO           False  2016           19486                  False
#
#     crimes_estimated  state_population  violent_crime_total  \
# 6              False         4430989.0              15492.0
# 57             False         4501051.0              15882.0
# 108            False         4547633.0              15757.0
# 159            False         4601821.0              17121.0
# 210            False         4663295.0              18498.0
# 261            False         4753377.0              18794.0
# 312            False         4861515.0              17101.0
# 363            False         4939456.0              17480.0
# 414            False         5024748.0              17022.0
# 465            False         5047692.0              16339.0
# 516            False         5116302.0              16085.0
# 567            False         5189458.0              15951.0
# 618            False         5272086.0              16099.0
# 669            False         5355866.0              16554.0
# 720            False         5456574.0              17515.0
# 771            False         5530105.0              19030.0
#
#      murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
#
der_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 43                1332.0       8169.0           NaN  35348.0      77306.0
# 94                1302.0       8508.0           NaN  37580.0      78628.0
# 145               1422.0       8025.0           NaN  37017.0      75782.0
# 196               1364.0       8388.0           NaN  35817.0      75985.0
# 247               1407.0       8511.0           NaN  35790.0      75383.0
# 298               1386.0       8429.0           NaN  37256.0      74531.0
# 349               1419.0       8460.0           NaN  38778.0      73357.0
# 400               1370.0       8055.0           NaN  37739.0      76421.0
# 451               1330.0       8311.0           NaN  38022.0      74021.0
# 502               1249.0       7622.0           NaN  32843.0      71517.0
# 553               1130.0       7486.0           NaN  28620.0      67498.0
# 604               1148.0       7715.0           NaN  30385.0      67227.0
# 655               1140.0       7610.0       10456.0  31810.0      65351.0
# 706               1184.0       8236.0       11393.0  31181.0      65656.0
# 757               1316.0       8925.0       12250.0  31934.0      67727.0
# 808               1478.0          NaN       13446.0  33298.0      72842.0
#
#      property_crime_total  burglary   larceny  vehicle_theft
# 43               976654.0  204362.0  669625.0       102667.0
# 94              1004274.0  212602.0  688992.0       102680.0
# 145             1016735.0  219877.0  698644.0        98214.0
# 196             1010702.0  220118.0  696507.0        94077.0
# 247              990293.0  219828.0  677042.0        93423.0
# 298              959846.0  215710.0  648711.0        95425.0
# 349              985421.0  228320.0  663101.0        94000.0
# 400              969865.0  230046.0  654435.0        85384.0
# 451              995082.0  240058.0  678455.0        76569.0
# 502              951246.0  228597.0  654626.0        68023.0
# 553              892810.0  215755.0  613131.0        63924.0
# 604              876459.0  205002.0  606425.0        65032.0
# 655              862289.0  191062.0  605440.0        65787.0
# 706              813934.0  169234.0  576154.0        68546.0
# 757              777739.0  153054.0  557200.0        67485.0
# 808              769892.0  148796.0  552106.0        68990.0

# %%
year = crime_df_colorado['year']
prisoner_count_colorado = crime_df_colorado['prisoner_count']
figure = plt.figure()

plt.plot(year, prisoner_count_colorado, 'r', marker='o')
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_count_colorado), max(prisoner_count_colorado)], 'k-')
plt.xlabel('YEAR')
plt.ylabel('PRISONER COUNT IN COLORADO')

plt.grid()
figure.savefig('Incarceration_by_year_Colorado.jpg')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
year = crime_df_texas['year']
prisoner_count_texas = crime_df_texas['prisoner_count']
figure = plt.figure()

plt.plot(year, prisoner_count_texas, 'r', marker='o')
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_count_texas), max(prisoner_count_texas)], 'k-')
plt.xlabel('YEAR')
plt.ylabel('PRISONER COUNT IN TEXAS')

#figure.savefig('Incarceration_by_year_Texas.jpg')
plt.grid()

plt.show()
figure.savefig('Incarceration_by_year_Texas.jpg')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
prisoner_per_capita_colorado = crime_df_colorado['prisoner_count']/crime_df_colorado['state_population']
figure = plt.figure()
plt.plot(year, prisoner_per_capita_colorado, marker='o')
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_per_capita_colorado), max(prisoner_per_capita_colorado)], 'k-')
plt.xlabel('YEAR')
plt.ylabel('PRISONER COUNT PER CAPITA IN COLORADO')
figure.savefig('Incarceration_rate_by_year_Colorado.jpg')
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
prisoner_per_capita_texas = crime_df_texas['prisoner_count']/crime_df_texas['state_population']
figure = plt.figure()
plt.plot(year, prisoner_per_capita_texas, marker='o')
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_per_capita_texas), max(prisoner_per_capita_texas)], 'k-')
plt.xlabel('YEAR')
plt.ylabel('PRISONER COUNT PER CAPITA IN TEXAS')
figure.savefig('Incarceration_rate_by_year_Texas.jpg')
plt.show()
plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
crime_df_texas = crime_df[crime_df['jurisdiction']=='TEXAS']
crime_df_texas.head()
# Out:
#     jurisdiction  includes_jails  year  prisoner_count crime_reporting_change  \
# 43         TEXAS           False  2001          148480                  False
# 94         TEXAS           False  2002          152446                  False
# 145        TEXAS           False  2003          153056                  False
# 196        TEXAS           False  2004          156682                  False
# 247        TEXAS           False  2005          157081                  False
#
#     crimes_estimated  state_population  violent_crime_total  \
# 43             False        21370983.0             122155.0
# 94             False        21736925.0             126018.0
# 145            False        22103374.0             122246.0
# 196            False        22471549.0             121554.0
# 247            False        22928508.0             121091.0
#
#      murder_manslaughter  rape_legacy  rape_revised  robbery  agg_assault  \
# 43                1332.0       8169.0           NaN  35348.0      77306.0
# 94                1302.0       8508.0           NaN  37580.0      78628.0
# 145               1422.0       8025.0           NaN  37017.0      75782.0
# 196               1364.0       8388.0           NaN  35817.0      75985.0
# 247               1407.0       8511.0           NaN  35790.0      75383.0
#
#      property_crime_total  burglary   larceny  vehicle_theft
# 43               976654.0  204362.0  669625.0       102667.0
# 94              1004274.0  212602.0  688992.0       102680.0
# 145             1016735.0  219877.0  698644.0        98214.0
# 196             1010702.0  220118.0  696507.0        94077.0
# 247              990293.0  219828.0  677042.0        93423.0

# %%
figure = plt.figure()
prisoner_count_texas = crime_df_texas['prisoner_count']
plt.plot('year', 'prisoner_count', data=crime_df_colorado, label='colorado', marker='o')
plt.plot('year', 'prisoner_count', data=crime_df_texas, label='texas', marker='o')
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_count_colorado), max(prisoner_count_colorado)], 'k-')
plt.xlabel('YEAR')
plt.ylabel('PRISONER COUNT')
figure.savefig('Incarceration_by_year_texas_colorado.jpg')
plt.rcParams['figure.figsize']= [10,5]
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
crime_df_ltd=crime_df[crime_df['jurisdiction'].isin([
    'TEXAS',
    'COLORADO', 
])]

col = crime_df_ltd.apply(fn, axis=1) # get column data with an index
crime_df_ltd = crime_df_ltd.assign(crime_per_capita=col.values) 
prisoner_count_texas = crime_df_texas

crime_df_ltd['crime_per_capita'] = crime_df_ltd['prisoner_count']/crime_df_ltd['state_population']
fig, ax = plt.subplots(1,1);
crime_df_ltd.groupby("jurisdiction").plot(x="year", y="crime_per_capita", ax=ax, marker='o', grid=True)
plt.rcParams['figure.figsize']= [10,5]
plt.legend([v[0] for v in crime_df_ltd.groupby('jurisdiction')['jurisdiction']], loc='best') 
plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_per_capita_colorado), max(prisoner_per_capita_colorado)], 'k-')

plt.plot([MARIJUANA_LEGALIZATION_YEAR, MARIJUANA_LEGALIZATION_YEAR], [min(prisoner_per_capita_texas), max(prisoner_per_capita_texas)], 'k-')
plt.xlabel('year')
plt.title('Prisoner Count Per Capita Comparison', fontdict=font)
plt.ylabel('prisoner count per capita')
fig.savefig('prisoner_count_per_capita_comparison.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-199b07a4caae> in <module>
#       4 ])]
#       5
# ----> 6 col = crime_df_ltd.apply(fn, axis=1) # get column data with an index
#       7 crime_df_ltd = crime_df_ltd.assign(crime_per_capita=col.values)
#       8 prisoner_count_texas = crime_df_texas
#
# NameError: name 'fn' is not defined
