# %%
import pandas as pd
import matplotlib.pyplot as plt

age_groups = ("12 or Older", "12 to 17", "18 or Older", "18 to 25", "26 or Older")

# %%
# Graph for first time Using Marijuana in Colorado Based by Age.

#Read data into data frames
ftmu_file = "./First_Time_Marijuana_Use_All_Ages_Colorado_2002-2017.csv"
Colorado_First_Use_df =  pd.read_csv(ftmu_file)

#Break out age ranges into separate data frames
ftmu_12_older_df = Colorado_First_Use_df.loc[Colorado_First_Use_df['age_group']==age_groups[0]]
ftmu_12_17_df = Colorado_First_Use_df.loc[Colorado_First_Use_df['age_group']==age_groups[1]]
ftmu_18_older_df = Colorado_First_Use_df.loc[Colorado_First_Use_df['age_group']==age_groups[2]]
ftmu_18_25_df = Colorado_First_Use_df.loc[Colorado_First_Use_df['age_group']==age_groups[3]]
ftmu_26_older_df = Colorado_First_Use_df.loc[Colorado_First_Use_df['age_group']==age_groups[4]]

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
plt.plot(ftmu_12_older_df["year_pair"], ftmu_12_older_df["estimate"], 'ro-', alpha=0.5, label=age_groups[0])
plt.plot(ftmu_12_17_df["year_pair"], ftmu_12_17_df["estimate"],'bo-', alpha=0.5, label=age_groups[1])
plt.plot(ftmu_18_older_df["year_pair"], ftmu_18_older_df["estimate"], 'go-', alpha=0.5, label=age_groups[2])
plt.plot(ftmu_18_25_df["year_pair"], ftmu_18_25_df["estimate"], 'co-', alpha=0.5, label=age_groups[3])
plt.plot(ftmu_26_older_df["year_pair"], ftmu_26_older_df["estimate"], 'mo-', alpha=0.5, label=age_groups[4])

# Add title, axis names, and legend
plt.title('First Time Marijuana Use in Colorado by Age')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Age Groups", fontsize="large", loc="best")

plt.show()

# %%
# Graph for First Time Marijuana Use 18-25: CO, TX, US.

#Read data into data frames
#ftmu_file = "./First_Time_Marijuana_Use_All_Ages_Colorado_2002-2017.csv"
#Colorado_First_Use_df =  pd.read_csv(ftmu_file)

ftmu_file_TX = "./First_Time_Marijuana_Use_Ages18-25_Texas_2002-2017.csv"
TX_First_Use_df =  pd.read_csv(ftmu_file_TX)

ftmu_file_US = "./First_Time_Marijuana_Use_Ages18-25_United_States_2002-2017.csv"
US_First_Use_df =  pd.read_csv(ftmu_file_US)

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
plt.plot(ftmu_18_25_df["year_pair"], ftmu_18_25_df["estimate"], 'co-', alpha=0.5, label="CO 18 to 25")
plt.plot(TX_First_Use_df["year_pair"], TX_First_Use_df["estimate"], 'yo-', alpha=0.5, label="TX 18 to 25")
plt.plot(US_First_Use_df["year_pair"], US_First_Use_df["estimate"], 'ko-', alpha=0.5, label="US 18 to 25")

# Add title, axis names, and legend
plt.title('First Time Marijuana Use 18-25: CO, TX, US')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()

# %%
#matplotlib.colors
#b : blue.
#g : green.
#r : red.
#c : cyan.
#m : magenta.
#y : yellow.
#k : black.
#w : white.

# %%
#Past Month Use 18-25: CO, TX, US: Marijuana, Alcohol, Cigarette

#Note: Alcohol is misspelled in the file names...
#Note: Year is wrong too, 20017?...
#Note: Inconsistent file naming, Age, Ages...

pmmu_file_CO = "./Marijuana_PastMonth_Ages_18-25_Colorado_2002-2017.csv"
CO_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_CO)
pmmu_file_TX = "./Marijuana_PastMonth_Ages_18-25_Texas_2002-2017.csv"
TX_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_TX)
pmmu_file_US = "./Marijuana_PastMonth_Ages_18-25_United_States_2002-2017.csv"
US_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_US)

pmau_file_CO = "./Alchohal_PastMonth_Age18-25_2002-20017_Colorado.csv"
CO_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_CO)
pmau_file_US = "./Alchohal_PastMonth_Age18-25_2002-20017_United_States.csv"
US_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_US)
pmau_file_TX = "./Alchohal_PastMonth_Ages18-25_2002-20017_Texas.csv"
TX_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_TX)

pmcu_file_CO = "./Cigarette_PastMonth_Age18-25_2002-20017_Colorado.csv"
CO_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_CO)
pmcu_file_US = "./Cigarette_PastMonth_Age18-25_2002-20017_United_States.csv"
US_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_US)
pmcu_file_TX = "./Cigarette_PastMonth_Age18-25_2002-20017_Texas.csv"
TX_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_TX)

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
plt.plot(CO_Marijuana_PastMonth_18_25_df["year_pair"], CO_Marijuana_PastMonth_18_25_df["estimate"], 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")
plt.plot(TX_Marijuana_PastMonth_18_25_df["year_pair"], TX_Marijuana_PastMonth_18_25_df["estimate"], 'kv-', alpha=0.5, label="TX Marijuana 18 to 25")
plt.plot(US_Marijuana_PastMonth_18_25_df["year_pair"], US_Marijuana_PastMonth_18_25_df["estimate"], 'ks-', alpha=0.5, label="US Marijuana 18 to 25")

plt.plot(CO_Alcohol_PastMonth_18_25_df["year_pair"], CO_Alcohol_PastMonth_18_25_df["estimate"], 'ro-', alpha=0.5, label="CO Alcohol 18 to 25")
plt.plot(US_Alcohol_PastMonth_18_25_df["year_pair"], US_Alcohol_PastMonth_18_25_df["estimate"], 'go-', alpha=0.5, label="US Alcohol 18 to 25")
plt.plot(TX_Alcohol_PastMonth_18_25_df["year_pair"], TX_Alcohol_PastMonth_18_25_df["estimate"], 'bo-', alpha=0.5, label="TX Alcohol 18 to 25")

plt.plot(CO_Cigarette_PastMonth_18_25_df["year_pair"], CO_Cigarette_PastMonth_18_25_df["estimate"], 'co-', alpha=0.5, label="CO Cigarette 18 to 25")
plt.plot(US_Cigarette_PastMonth_18_25_df["year_pair"], US_Cigarette_PastMonth_18_25_df["estimate"], 'mo-', alpha=0.5, label="US Cigarette 18 to 25")
plt.plot(TX_Cigarette_PastMonth_18_25_df["year_pair"], TX_Cigarette_PastMonth_18_25_df["estimate"], 'yo-', alpha=0.5, label="TX Cigarette 18 to 25")

# Add title, axis names, and legend
plt.title('Past Month Use 18-25: CO, TX, US: Marijuana, Alcohol, Cigarette')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()

# %%
#Past Month Use 18-25: CO: Marijuana, Alcohol, Cigarette

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

CO_Marijuana_PastMonth_18_25_df["year_pair"] = CO_Marijuana_PastMonth_18_25_df["year_pair"].apply(lambda x: x.split('-')[0])
CO_Alcohol_PastMonth_18_25_df["year_pair"] = CO_Alcohol_PastMonth_18_25_df["year_pair"].apply(lambda x: x.split('-')[0])
CO_Cigarette_PastMonth_18_25_df["year_pair"] = CO_Cigarette_PastMonth_18_25_df["year_pair"].apply(lambda x: x.split('-')[0])

#Line Plots
plt.plot(CO_Marijuana_PastMonth_18_25_df["year_pair"], CO_Marijuana_PastMonth_18_25_df["estimate"]*100, 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")

plt.plot(CO_Alcohol_PastMonth_18_25_df["year_pair"], CO_Alcohol_PastMonth_18_25_df["estimate"]*100, 'ro-', alpha=0.5, label="CO Alcohol 18 to 25")

plt.plot(CO_Cigarette_PastMonth_18_25_df["year_pair"], CO_Cigarette_PastMonth_18_25_df["estimate"]*100, 'co-', alpha=0.5, label="CO Cigarette 18 to 25")

# Add title, axis names, and legend
plt.title('Past Month Use 18-25: CO: Marijuana, Alcohol, Cigarette')
plt.xlabel('Year')
plt.ylabel('Percent of Population')
plt.legend(title="Region", fontsize="large", loc="best")

plt.axvline(x="2012", linewidth=1, color='k')
plt.grid()

plt.rc('axes', labelsize=20)    # fontsize of the x and y labels
#plt.rc('font', size=30)          # controls default text sizes
#plt.rc('figure', titlesize=20)

plt.show()

# %%
#Past Year Mental Health

pymu_18_25_CO_file = "./MarijuanaUse_PastYear_18_25.csv"
pymu_18_25_CO_df =  pd.read_csv(pymu_18_25_CO_file)

pyami_18_25_CO_file = "./Any_Mental_Illness_PastYear_18_25.csv"
pyami_18_25_CO_df =  pd.read_csv(pyami_18_25_CO_file)

pysmi_18_25_CO_file = "./Serious_Mental_Illness_PastYear_18_25.csv"
pysmi_18_25_CO_df =  pd.read_csv(pysmi_18_25_CO_file)

pyst_18_25_CO_file = "./Suicide_Thoughts_PastYear_18_25.csv"
pyst_18_25_CO_df =  pd.read_csv(pyst_18_25_CO_file)

pymde_18_25_CO_file = "./Major_Depressive_Episode_PastYear_18_25.csv"
pymde_18_25_CO_df =  pd.read_csv(pymde_18_25_CO_file)

pyrmhs_18_25_CO_file = "./Received_MH_Services_PastYear_18_25.csv"
pyrmhs_18_25_CO_df =  pd.read_csv(pyrmhs_18_25_CO_file)

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
plt.plot(pymu_18_25_CO_df["year_pair"], pymu_18_25_CO_df["estimate"], 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")
plt.plot(pyami_18_25_CO_df["year_pair"], pyami_18_25_CO_df["estimate"], 'yo-', alpha=0.5, label="CO Any Mental Illness 18 to 25")
plt.plot(pysmi_18_25_CO_df["year_pair"], pysmi_18_25_CO_df["estimate"], 'go-', alpha=0.5, label="CO Serious Mental Illness 18 to 25")
plt.plot(pyst_18_25_CO_df["year_pair"], pyst_18_25_CO_df["estimate"], 'ro-', alpha=0.5, label="CO Suicidal Thoughts 18 to 25")
plt.plot(pymde_18_25_CO_df["year_pair"], pymde_18_25_CO_df["estimate"], 'co-', alpha=0.5, label="CO Major Depressive Episode 18 to 25")
plt.plot(pyrmhs_18_25_CO_df["year_pair"], pyrmhs_18_25_CO_df["estimate"], 'mo-', alpha=0.5, label="CO Received Mental Health Services 18 to 25")

# Add title, axis names, and legend
plt.title('Past Year Mental Health 18-25 CO')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()

# %%
#Past Month Use 18-25: CO, TX, US: Marijuana, Alcohol, Cigarette

#Note: Alcohol is misspelled in the file names...
#Note: Year is wrong too, 20017?...
#Note: Inconsistent file naming, Age, Ages...

pmmu_file_CO = "./Marijuana_PastMonth_Ages_18-25_Colorado_2002-2017.csv"
CO_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_CO)
pmmu_file_TX = "./Marijuana_PastMonth_Ages_18-25_Texas_2002-2017.csv"
TX_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_TX)
pmmu_file_US = "./Marijuana_PastMonth_Ages_18-25_United_States_2002-2017.csv"
US_Marijuana_PastMonth_18_25_df =  pd.read_csv(pmmu_file_US)

pmau_file_CO = "./Alchohal_PastMonth_Age18-25_2002-20017_Colorado.csv"
CO_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_CO)
pmau_file_US = "./Alchohal_PastMonth_Age18-25_2002-20017_United_States.csv"
US_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_US)
pmau_file_TX = "./Alchohal_PastMonth_Ages18-25_2002-20017_Texas.csv"
TX_Alcohol_PastMonth_18_25_df =  pd.read_csv(pmau_file_TX)

pmcu_file_CO = "./Cigarette_PastMonth_Age18-25_2002-20017_Colorado.csv"
CO_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_CO)
pmcu_file_US = "./Cigarette_PastMonth_Age18-25_2002-20017_United_States.csv"
US_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_US)
pmcu_file_TX = "./Cigarette_PastMonth_Age18-25_2002-20017_Texas.csv"
TX_Cigarette_PastMonth_18_25_df =  pd.read_csv(pmcu_file_TX)

#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
plt.plot(CO_Marijuana_PastMonth_18_25_df["year_pair"], CO_Marijuana_PastMonth_18_25_df["estimate"], 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")
plt.plot(TX_Marijuana_PastMonth_18_25_df["year_pair"], TX_Marijuana_PastMonth_18_25_df["estimate"], 'kv-', alpha=0.5, label="TX Marijuana 18 to 25")
plt.plot(US_Marijuana_PastMonth_18_25_df["year_pair"], US_Marijuana_PastMonth_18_25_df["estimate"], 'ks-', alpha=0.5, label="US Marijuana 18 to 25")

#plt.plot(CO_Alcohol_PastMonth_18_25_df["year_pair"], CO_Alcohol_PastMonth_18_25_df["estimate"], 'ro-', alpha=0.5, label="CO Alcohol 18 to 25")
#plt.plot(US_Alcohol_PastMonth_18_25_df["year_pair"], US_Alcohol_PastMonth_18_25_df["estimate"], 'go-', alpha=0.5, label="US Alcohol 18 to 25")
#plt.plot(TX_Alcohol_PastMonth_18_25_df["year_pair"], TX_Alcohol_PastMonth_18_25_df["estimate"], 'bo-', alpha=0.5, label="TX Alcohol 18 to 25")

#plt.plot(CO_Cigarette_PastMonth_18_25_df["year_pair"], CO_Cigarette_PastMonth_18_25_df["estimate"], 'co-', alpha=0.5, label="CO Cigarette 18 to 25")
#plt.plot(US_Cigarette_PastMonth_18_25_df["year_pair"], US_Cigarette_PastMonth_18_25_df["estimate"], 'mo-', alpha=0.5, label="US Cigarette 18 to 25")
#plt.plot(TX_Cigarette_PastMonth_18_25_df["year_pair"], TX_Cigarette_PastMonth_18_25_df["estimate"], 'yo-', alpha=0.5, label="TX Cigarette 18 to 25")

# Add title, axis names, and legend
plt.title('Past Month Use 18-25: CO, TX, US: Marijuana')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()

# %%
#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
#plt.plot(CO_Marijuana_PastMonth_18_25_df["year_pair"], CO_Marijuana_PastMonth_18_25_df["estimate"], 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")
#plt.plot(TX_Marijuana_PastMonth_18_25_df["year_pair"], TX_Marijuana_PastMonth_18_25_df["estimate"], 'kv-', alpha=0.5, label="TX Marijuana 18 to 25")
#plt.plot(US_Marijuana_PastMonth_18_25_df["year_pair"], US_Marijuana_PastMonth_18_25_df["estimate"], 'ks-', alpha=0.5, label="US Marijuana 18 to 25")

plt.plot(CO_Alcohol_PastMonth_18_25_df["year_pair"], CO_Alcohol_PastMonth_18_25_df["estimate"], 'ro-', alpha=0.5, label="CO Alcohol 18 to 25")
plt.plot(US_Alcohol_PastMonth_18_25_df["year_pair"], US_Alcohol_PastMonth_18_25_df["estimate"], 'go-', alpha=0.5, label="US Alcohol 18 to 25")
plt.plot(TX_Alcohol_PastMonth_18_25_df["year_pair"], TX_Alcohol_PastMonth_18_25_df["estimate"], 'bo-', alpha=0.5, label="TX Alcohol 18 to 25")

#plt.plot(CO_Cigarette_PastMonth_18_25_df["year_pair"], CO_Cigarette_PastMonth_18_25_df["estimate"], 'co-', alpha=0.5, label="CO Cigarette 18 to 25")
#plt.plot(US_Cigarette_PastMonth_18_25_df["year_pair"], US_Cigarette_PastMonth_18_25_df["estimate"], 'mo-', alpha=0.5, label="US Cigarette 18 to 25")
#plt.plot(TX_Cigarette_PastMonth_18_25_df["year_pair"], TX_Cigarette_PastMonth_18_25_df["estimate"], 'yo-', alpha=0.5, label="TX Cigarette 18 to 25")

# Add title, axis names, and legend
plt.title('Past Month Use 18-25: CO, TX, US: Alcohol')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()

# %%
#Set plot size
plt.rcParams["figure.figsize"] = [20,10]

#Line Plots
#plt.plot(CO_Marijuana_PastMonth_18_25_df["year_pair"], CO_Marijuana_PastMonth_18_25_df["estimate"], 'ko-', alpha=0.5, label="CO Marijuana 18 to 25")
#plt.plot(TX_Marijuana_PastMonth_18_25_df["year_pair"], TX_Marijuana_PastMonth_18_25_df["estimate"], 'kv-', alpha=0.5, label="TX Marijuana 18 to 25")
#plt.plot(US_Marijuana_PastMonth_18_25_df["year_pair"], US_Marijuana_PastMonth_18_25_df["estimate"], 'ks-', alpha=0.5, label="US Marijuana 18 to 25")

#plt.plot(CO_Alcohol_PastMonth_18_25_df["year_pair"], CO_Alcohol_PastMonth_18_25_df["estimate"], 'ro-', alpha=0.5, label="CO Alcohol 18 to 25")
#plt.plot(US_Alcohol_PastMonth_18_25_df["year_pair"], US_Alcohol_PastMonth_18_25_df["estimate"], 'go-', alpha=0.5, label="US Alcohol 18 to 25")
#plt.plot(TX_Alcohol_PastMonth_18_25_df["year_pair"], TX_Alcohol_PastMonth_18_25_df["estimate"], 'bo-', alpha=0.5, label="TX Alcohol 18 to 25")

plt.plot(CO_Cigarette_PastMonth_18_25_df["year_pair"], CO_Cigarette_PastMonth_18_25_df["estimate"], 'co-', alpha=0.5, label="CO Cigarette 18 to 25")
plt.plot(US_Cigarette_PastMonth_18_25_df["year_pair"], US_Cigarette_PastMonth_18_25_df["estimate"], 'mo-', alpha=0.5, label="US Cigarette 18 to 25")
plt.plot(TX_Cigarette_PastMonth_18_25_df["year_pair"], TX_Cigarette_PastMonth_18_25_df["estimate"], 'yo-', alpha=0.5, label="TX Cigarette 18 to 25")

# Add title, axis names, and legend
plt.title('Past Month Use 18-25: CO, TX, US: Cigarette')
plt.xlabel('Year')
plt.ylabel('Percent')
plt.legend(title="Region", fontsize="large", loc="best")

plt.show()
