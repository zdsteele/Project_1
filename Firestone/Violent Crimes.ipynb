# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from pprint import pprint

# %%
violent_2008="08-17Crime/ViolentCrimes/2008ViolentCrimes.csv"
violent_2009="08-17Crime/ViolentCrimes/2009ViolentCrimes.csv"
violent_2010="08-17Crime/ViolentCrimes/2010ViolentCrimes.csv"
violent_2011="08-17Crime/ViolentCrimes/2011ViolentCrimes.csv"
violent_2012="08-17Crime/ViolentCrimes/2012ViolentCrimes.csv"
violent_2013="08-17Crime/ViolentCrimes/2013ViolentCrimes.csv"
violent_2014="08-17Crime/ViolentCrimes/2014ViolentCrimes.csv"
violent_2015="08-17Crime/ViolentCrimes/2015ViolentCrimes.csv"
violent_2016="08-17Crime/ViolentCrimes/2016ViolentCrimes.csv"
violent_2017="08-17Crime/ViolentCrimes/2017ViolentCrimes.csv"

violent_2008_df=pd.read_csv(violent_2008)
violent_2009_df=pd.read_csv(violent_2009)
violent_2010_df=pd.read_csv(violent_2010)
violent_2011_df=pd.read_csv(violent_2011)
violent_2012_df=pd.read_csv(violent_2012)
violent_2013_df=pd.read_csv(violent_2013)
violent_2014_df=pd.read_csv(violent_2014)
violent_2015_df=pd.read_csv(violent_2015)
violent_2016_df=pd.read_csv(violent_2016)
violent_2017_df=pd.read_csv(violent_2017)

# %%
combined_crimes=pd.merge(violent_2008_df,violent_2009_df,how='outer',on='Offense Type')

combined_crimes.head()
# Out:
#                   Offense Type Number of Crimes_x  Crime Rate (per 100,000)_x  \
# 0                Violent Crime             17,737                      358.71
# 1                       Murder                138                        2.79
# 2           Aggravated Assault             10,095                      204.16
# 3  Non-consensual Sex Offenses              4,465                       90.30
# 4                      Robbery              3,039                       61.46
#
#   Number of Crimes_y  Crime Rate (per 100,000)_y
# 0             17,607                      350.16
# 1                126                        2.51
# 2              9,785                      194.60
# 3              4,641                       92.30
# 4              3,055                       60.76

# %%
combined_crimes=combined_crimes.rename(columns={"Number of Crimes_x":"2008 Crimes",
                                                "Crime Rate (per 100,000)_x":"2008",
                                                "Number of Crimes_y":"2009 Crimes",
                                                "Crime Rate (per 100,000)_y":"2009"  
})

combined_crimes.head()
# Out:
#                   Offense Type 2008 Crimes    2008 2009 Crimes    2009
# 0                Violent Crime      17,737  358.71      17,607  350.16
# 1                       Murder         138    2.79         126    2.51
# 2           Aggravated Assault      10,095  204.16       9,785  194.60
# 3  Non-consensual Sex Offenses       4,465   90.30       4,641   92.30
# 4                      Robbery       3,039   61.46       3,055   60.76

# %%
combined_crimes=pd.merge(combined_crimes,violent_2010_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2010 Crimes",
                                                "Crime Rate (per 100,000)":"2010"
                                               })
combined_crimes.head()
# Out:
#                   Offense Type 2008 Crimes    2008 2009 Crimes    2009  \
# 0                Violent Crime      17,737  358.71      17,607  350.16
# 1                       Murder         138    2.79         126    2.51
# 2           Aggravated Assault      10,095  204.16       9,785  194.60
# 3  Non-consensual Sex Offenses       4,465   90.30       4,641   92.30
# 4                      Robbery       3,039   61.46       3,055   60.76
#
#   2010 Crimes    2010
# 0      17,436  346.50
# 1          93    1.85
# 2       9,707  192.91
# 3       4,687   93.14
# 4       2,949   58.61

# %%
combined_crimes=pd.merge(combined_crimes,violent_2011_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2011 Crimes",
                                                "Crime Rate (per 100,000)":"2011"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2012_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2012 Crimes",
                                                "Crime Rate (per 100,000)":"2012"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2013_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2013 Crimes",
                                                "Crime Rate (per 100,000)":"2013"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2014_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2014 Crimes",
                                                "Crime Rate (per 100,000)":"2014"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2015_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2015 Crimes",
                                                "Crime Rate (per 100,000)":"2015"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2016_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2016 Crimes",
                                                "Crime Rate (per 100,000)":"2016"
                                               })

# %%
combined_crimes=pd.merge(combined_crimes,violent_2017_df,how='outer',on='Offense Type')

combined_crimes=combined_crimes.rename(columns={"Number of Crimes":"2017 Crimes",
                                                "Crime Rate (per 100,000)":"2017"
                                               })
combined_crimes.head()
# Out:
#                   Offense Type 2008 Crimes    2008 2009 Crimes    2009  \
# 0                Violent Crime      17,737  358.71      17,607  350.16
# 1                       Murder         138    2.79         126    2.51
# 2           Aggravated Assault      10,095  204.16       9,785  194.60
# 3  Non-consensual Sex Offenses       4,465   90.30       4,641   92.30
# 4                      Robbery       3,039   61.46       3,055   60.76
#
#   2010 Crimes    2010 2011 Crimes    2011 2012 Crimes  ...  2013 Crimes  \
# 0      17,436  346.50      17,358  339.05      19,243  ...       18,475
# 1          93    1.85         139    2.72         162  ...          175
# 2       9,707  192.91       9,131  178.35      10,180  ...        9,713
# 3       4,687   93.14       4,892   95.55       5,546  ...        5,435
# 4       2,949   58.61       3,196   62.43       3,355  ...        3,152
#
#      2013  2014 Crimes    2014  2015 Crimes    2015  2016 Crimes    2016  \
# 0  350.44       18,814  350.63       19,947  364.77       21,608  395.21
# 1    3.32          151    2.81          173    3.16          190    3.48
# 2  184.24       10,148  189.12       10,611  194.04       11,791  215.66
# 3  103.09        5,481  102.15        5,835  106.70        6,072  111.06
# 4   59.79        3,034   56.54        3,328   60.86        3,555   65.02
#
#    2017 Crimes    2017
# 0       23,343  415.22
# 1          218    3.88
# 2       12,780  227.33
# 3        6,513  115.85
# 4        3,832   68.16
#
# [5 rows x 21 columns]

# %%
#Convert rate per 100,000 to percentage, cross reference with estimate percentage in marijuanaDF
#convert by multiplying estimate percentage by 1,000
#then name graph per 100,000 effected

# %%
marijuana='../Drug_Data_Years_Zach/Marijuana_PastMonth_All_Ages_Colorado_2002-2017.csv'

marijuanaUseDF=pd.read_csv(marijuana)
marijuanaUseDF.head()
# Out:
#                            outcome    age_group year_pair geography  estimate  \
# 0  Marijuana Use in the Past Month  12 or Older   2002-03  Colorado  0.084905
# 1  Marijuana Use in the Past Month  12 or Older   2003-04  Colorado  0.073297
# 2  Marijuana Use in the Past Month  12 or Older   2004-05  Colorado  0.075309
# 3  Marijuana Use in the Past Month  12 or Older   2005-06  Colorado  0.077573
# 4  Marijuana Use in the Past Month  12 or Older   2006-07  Colorado  0.081342
#
#    ci_lower  ci_upper
# 0  0.071134  0.101053
# 1  0.061234  0.087515
# 2  0.063525  0.089071
# 3  0.065206  0.092054
# 4  0.068565  0.096255

# %%
marijuanaByYear=marijuanaUseDF.groupby('year_pair').sum()
marijuanaByYear
# Out:
#            estimate  ci_lower  ci_upper
# year_pair
# 2002-03    0.543284  0.449920  0.653907
# 2003-04    0.480550  0.394956  0.582823
# 2004-05    0.500089  0.413007  0.603538
# 2005-06    0.497612  0.411594  0.599332
# 2006-07    0.519810  0.432997  0.621595
# 2007-08    0.578317  0.477778  0.696909
# 2008-09    0.611528  0.506298  0.735526
# 2009-10    0.678349  0.569213  0.805279
# 2010-11    0.681546  0.574362  0.805458
# 2011-12    0.657280  0.553864  0.777399
# 2012-13    0.758975  0.643415  0.891467
# 2013-14    0.863405  0.744057  0.997790
# 2014-15    0.912073  0.791987  1.046244
# 2015-16    0.878168  0.760730  1.009351
# 2016-17    0.891705  0.771853  1.025408

# %%
marijuanaByYear['estimate']=marijuanaByYear['estimate']*1000

# %%
marijuanaByYear
# Out:
#            estimate  ci_lower  ci_upper
# year_pair
# 2002-03     543.284  0.449920  0.653907
# 2003-04     480.550  0.394956  0.582823
# 2004-05     500.089  0.413007  0.603538
# 2005-06     497.612  0.411594  0.599332
# 2006-07     519.810  0.432997  0.621595
# 2007-08     578.317  0.477778  0.696909
# 2008-09     611.528  0.506298  0.735526
# 2009-10     678.349  0.569213  0.805279
# 2010-11     681.546  0.574362  0.805458
# 2011-12     657.280  0.553864  0.777399
# 2012-13     758.975  0.643415  0.891467
# 2013-14     863.405  0.744057  0.997790
# 2014-15     912.073  0.791987  1.046244
# 2015-16     878.168  0.760730  1.009351
# 2016-17     891.705  0.771853  1.025408

# %%
marijuanaByYear.reset_index(inplace = True)

# %%
marijuanaByYear['year_pair'] = marijuanaByYear['year_pair'].apply(lambda x: x.split('-')[0])

# %%
marijuanaByYear
# Out:
#    year_pair  estimate  ci_lower  ci_upper
# 0       2002   543.284  0.449920  0.653907
# 1       2003   480.550  0.394956  0.582823
# 2       2004   500.089  0.413007  0.603538
# 3       2005   497.612  0.411594  0.599332
# 4       2006   519.810  0.432997  0.621595
# 5       2007   578.317  0.477778  0.696909
# 6       2008   611.528  0.506298  0.735526
# 7       2009   678.349  0.569213  0.805279
# 8       2010   681.546  0.574362  0.805458
# 9       2011   657.280  0.553864  0.777399
# 10      2012   758.975  0.643415  0.891467
# 11      2013   863.405  0.744057  0.997790
# 12      2014   912.073  0.791987  1.046244
# 13      2015   878.168  0.760730  1.009351
# 14      2016   891.705  0.771853  1.025408

# %%
marijuanaByYear=marijuanaByYear.drop('ci_lower',axis=1)
marijuanaByYear=marijuanaByYear.drop('ci_upper',axis=1)

marijuanaByYear=marijuanaByYear.drop([0,1,2,3,4,5])

marijuanaByYear
# Out:
#    year_pair  estimate
# 6       2008   611.528
# 7       2009   678.349
# 8       2010   681.546
# 9       2011   657.280
# 10      2012   758.975
# 11      2013   863.405
# 12      2014   912.073
# 13      2015   878.168
# 14      2016   891.705

# %%
marijuanaByYear=marijuanaByYear.rename(columns={'year_pair':'Year','estimate':'Estimate'})
marijuanaByYear
# Out:
#     Year  Estimate
# 6   2008   611.528
# 7   2009   678.349
# 8   2010   681.546
# 9   2011   657.280
# 10  2012   758.975
# 11  2013   863.405
# 12  2014   912.073
# 13  2015   878.168
# 14  2016   891.705

# %%
#Crime Rate per 100,000
crimeperrate=combined_crimes[['Offense Type','2008','2009','2010','2011','2012','2013','2014','2015',
                              '2016','2017']]
crimeperrate
# Out:
#                   Offense Type    2008    2009    2010    2011    2012  \
# 0                Violent Crime  358.71  350.16  346.50  339.05  370.68
# 1                       Murder    2.79    2.51    1.85    2.72    3.12
# 2           Aggravated Assault  204.16  194.60  192.91  178.35  196.10
# 3  Non-consensual Sex Offenses   90.30   92.30   93.14   95.55  106.83
# 4                      Robbery   61.46   60.76   58.61   62.43   64.63
#
#      2013    2014    2015    2016    2017
# 0  350.44  350.63  364.77  395.21  415.22
# 1    3.32    2.81    3.16    3.48    3.88
# 2  184.24  189.12  194.04  215.66  227.33
# 3  103.09  102.15  106.70  111.06  115.85
# 4   59.79   56.54   60.86   65.02   68.16

# %%
crimeperrate=crimeperrate.T
crimeperrate
# Out:
#                           0       1                   2  \
# Offense Type  Violent Crime  Murder  Aggravated Assault
# 2008                 358.71    2.79              204.16
# 2009                 350.16    2.51               194.6
# 2010                  346.5    1.85              192.91
# 2011                 339.05    2.72              178.35
# 2012                 370.68    3.12               196.1
# 2013                 350.44    3.32              184.24
# 2014                 350.63    2.81              189.12
# 2015                 364.77    3.16              194.04
# 2016                 395.21    3.48              215.66
# 2017                 415.22    3.88              227.33
#
#                                         3        4
# Offense Type  Non-consensual Sex Offenses  Robbery
# 2008                                 90.3    61.46
# 2009                                 92.3    60.76
# 2010                                93.14    58.61
# 2011                                95.55    62.43
# 2012                               106.83    64.63
# 2013                               103.09    59.79
# 2014                               102.15    56.54
# 2015                                106.7    60.86
# 2016                               111.06    65.02
# 2017                               115.85    68.16

# %%
crimeperrate=crimeperrate.reset_index()
crimeperrate
# Out:
#            index              0       1                   2  \
# 0   Offense Type  Violent Crime  Murder  Aggravated Assault
# 1           2008         358.71    2.79              204.16
# 2           2009         350.16    2.51               194.6
# 3           2010          346.5    1.85              192.91
# 4           2011         339.05    2.72              178.35
# 5           2012         370.68    3.12               196.1
# 6           2013         350.44    3.32              184.24
# 7           2014         350.63    2.81              189.12
# 8           2015         364.77    3.16              194.04
# 9           2016         395.21    3.48              215.66
# 10          2017         415.22    3.88              227.33
#
#                               3        4
# 0   Non-consensual Sex Offenses  Robbery
# 1                          90.3    61.46
# 2                          92.3    60.76
# 3                         93.14    58.61
# 4                         95.55    62.43
# 5                        106.83    64.63
# 6                        103.09    59.79
# 7                        102.15    56.54
# 8                         106.7    60.86
# 9                        111.06    65.02
# 10                       115.85    68.16

# %%
crimeperrate=crimeperrate.rename(columns={'index':'Year',0:'Violent Crime',1:'Murder',
                                         2:'Aggravated Assault',3:'Non-Consensual Sex Offenses',4:'Robbery'})
crimeperrate=crimeperrate.drop([0,10])
#crimeperrate=crimeperrate.drop(crimeperrate.index[10])
crimeperrate
# Out:
#    Year Violent Crime Murder Aggravated Assault Non-Consensual Sex Offenses  \
# 1  2008        358.71   2.79             204.16                        90.3
# 2  2009        350.16   2.51              194.6                        92.3
# 3  2010         346.5   1.85             192.91                       93.14
# 4  2011        339.05   2.72             178.35                       95.55
# 5  2012        370.68   3.12              196.1                      106.83
# 6  2013        350.44   3.32             184.24                      103.09
# 7  2014        350.63   2.81             189.12                      102.15
# 8  2015        364.77   3.16             194.04                       106.7
# 9  2016        395.21   3.48             215.66                      111.06
#
#   Robbery
# 1   61.46
# 2   60.76
# 3   58.61
# 4   62.43
# 5   64.63
# 6   59.79
# 7   56.54
# 8   60.86
# 9   65.02

# %%
marijuanaByYear
# Out:
#     Year  Estimate
# 6   2008   611.528
# 7   2009   678.349
# 8   2010   681.546
# 9   2011   657.280
# 10  2012   758.975
# 11  2013   863.405
# 12  2014   912.073
# 13  2015   878.168
# 14  2016   891.705

# %%
plt.rcParams["figure.figsize"] = [20,10]

plt.plot(marijuanaByYear['Year'],marijuanaByYear['Estimate'],'ko-',linewidth='3',alpha=.5,label='Marijuana Use')
plt.plot(crimeperrate['Year'],crimeperrate['Violent Crime'],'bo-',linewidth='3',alpha=.5,label='Violent Crime')
plt.plot(crimeperrate['Year'],crimeperrate['Murder'],'ro-',linewidth='3',alpha=.5,label='Murder')
plt.plot(crimeperrate['Year'],crimeperrate['Aggravated Assault'],'yo-',linewidth='3',alpha=.5,
         label='Aggravated Assault')
plt.plot(crimeperrate['Year'],crimeperrate['Non-Consensual Sex Offenses'],'co-',linewidth='3',alpha=.5,
         label='Non-Consensual Sex Offenses')
plt.plot(crimeperrate['Year'],crimeperrate['Robbery'],'mo-',alpha=.5,label='Robbery')

plt.axvline(x='2012',linewidth='3',color='r')

plt.title('Marijuana Use and Crime Rates (per 100,000)',fontsize='30')
plt.xlabel('Year',fontsize='30')
plt.ylabel('Rates (per 100,000)',fontsize='30')
plt.legend(fontsize="large", loc="best")

plt.grid()
plt.show()

# %%
violent=crimeperrate.loc[crimeperrate['Offense Type']=='Violent Crime']
murder=crimeperrate.loc[crimeperrate['Offense Type']=='Murder']
aggravatedAssault=crimeperrate.loc[crimeperrate['Offense Type']=='Aggravated Assault']
nonConsensual=crimeperrate.loc[crimeperrate['Offense Type']=='Non-consensual Sex Offenses']
robbery=crimeperrate.loc[crimeperrate['Offense Type']=='Robbery']

plt.rcParams["figure.figsize"] = [20,10]

plt.plot(years,marijuanaData['Statistics'],'bo-',alpha=.5,label='Marijuana Use')
